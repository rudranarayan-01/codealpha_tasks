# %%
import numpy as np 
import cv2
import matplotlib
from matplotlib import pyplot as plt
# %matplotlib inline

# %%
# Read an image
img = cv2.imread("./test_images/sharapova1.JPG")
img.shape
# Out:
# (555, 700, 3)

# %%
plt.imshow(img)

# %%
# Removing the gray index or third value
gray = cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
gray.shape
# Out:
# (555, 700)

# %%
plt.imshow(gray, cmap="gray")

# %% [markdown]
# Haar CasCade: To detect images by considering dark and bright masks
